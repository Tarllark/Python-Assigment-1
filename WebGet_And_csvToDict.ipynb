# %% [raw]
# Webget:
# Main program: get_files.py
#     Arguments:
#         • uri for file to download
# Module: webget.py
#     Arguments:
#         • uri for file to download
#         • Location for download (!NOT FILE NAME)
# Description:
#     Automated installation of file from http servers. Files will be downloaded to a subfolder named downloads where the program
#     is placed.
#     To change download location open "get_files.py" in a text editor, eg. notepad, and change line 10: webget.download(url, "./downloads/) to
#     webget.download(url, "<new_location>")

# %%
# !rm ./downloads/*.txt
print("Before downloading:")
# !ls downloads/
# !python get_files.py http://www.gutenberg.org/files/2701/2701-0.txt http://www.gutenberg.org/cache/epub/27525/pg27525.txt
print("\n\nAfter downloading")
# !ls downloads/
# Out:
# Before downloading:
#
#
# After downloading
# 2701-0.txt
# pg27525.txt

# %% [raw]
# CSV to Dictionary converter:
# Title: csvToDict.py
#     Arguments:
#         • None
# Description:
#     Converts designated .csv file into a python dictionary

# %%
# !python csvToDict.py
# Out:
# Beginning conversion
# {'1992': {'1': {'103': {'5100': '1'}},
#           '10': {'102': {'5100': '2'}},
#           '2': {'103': {'5100': '1'}},
#           '3': {'103': {'5100': '1'}},
#           '4': {'102': {'5100': '1'}},
#           '5': {'102': {'5100': '1'}},
#           '6': {'104': {'5100': '1'}},
#           '7': {'102': {'5100': '3'}},
#           '8': {'105': {'5100': '1'}},
#           '9': {'101': {'5100': '2'}},
#           '99': {'93': {'5100': '1'}}},
#  '1993': {'1': {'104': {'5100': '1'}},
#           '10': {'103': {'5100': '2'}},
#           '2': {'104': {'5100': '1'}},
#           '3': {'101': {'5100': '1'}},
#           '4': {'100': {'5100': '1'}},
#           '5': {'103': {'5100': '1'}},
#           '6': {'105': {'5100': '1'}},
#           '7': {'103': {'5100': '3'}},
#           '8': {'106': {'5100': '1'}},
#           '9': {'102': {'5100': '2'}},
#           '99': {'94': {'5100': '1'}}},
#  '1994': {'1': {'102': {'5100': '1'}},
# ...
